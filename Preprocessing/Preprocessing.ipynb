# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import igraph
import networkx as nx
import seaborn as sns

# %%
test_df = pd.read_csv("Downloads/sign/sign_mnist_test.csv")
train_df = pd.read_csv("Downloads/sign/sign_mnist_train.csv")

# %%
test_df.shape
# Out:
# (7172, 785)

# %%
test_df.columns
# Out:
# Index(['label', 'pixel1', 'pixel2', 'pixel3', 'pixel4', 'pixel5', 'pixel6',
#        'pixel7', 'pixel8', 'pixel9',
#        ...
#        'pixel775', 'pixel776', 'pixel777', 'pixel778', 'pixel779', 'pixel780',
#        'pixel781', 'pixel782', 'pixel783', 'pixel784'],
#       dtype='object', length=785)

# %%
plt.figure(figsize = (10,10)) # Label Count
sns.set_style("darkgrid")
sns.countplot(train_df['label'])
plt.savefig('foo.png')
# Out:
# C:\Users\yunch\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
from sklearn.preprocessing import LabelBinarizer
label_binarizer = LabelBinarizer()
y_train = label_binarizer.fit_transform(train_df['label'])
y_test = label_binarizer.fit_transform(test_df['label'])
X_train = train_df.iloc[:,1:785].to_numpy()
X_test = test_df.iloc[:,1:785].to_numpy()
X_train.shape
# Out:
# (27455, 784)

# %%
X_train = X_train / 255
X_test = X_test / 255

# %%
X_train = X_train.reshape(-1,28,28,1)
X_test = X_test.reshape(-1,28,28,1)

# %%
f, ax = plt.subplots(4,5) 
f.set_size_inches(10, 10)
k = 0
for i in range(4):
    for j in range(5):
        ax[i,j].imshow(X_train[k].reshape(28, 28) , cmap = "gray")
        k += 1
    plt.tight_layout()
